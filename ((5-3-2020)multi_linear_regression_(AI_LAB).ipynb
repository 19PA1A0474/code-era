# %% [markdown]
# <a href="https://colab.research.google.com/github/19PA1A0474/code-era/blob/master/multi_linear_regression_(AI_LAB).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
from sklearn import metrics

# %%
j=pd.read_csv('students_placement_data.csv')
j
# Out:
#      Roll No Gender  ... registered_for_ Placement_Training  placement status
# 0          1      M  ...                                 NO        Not placed
# 1          2      F  ...                                yes            Placed
# 2          3      F  ...                                yes        Not placed
# 3          4      M  ...                                yes        Not placed
# 4          5      M  ...                                yes        Not placed
# ..       ...    ...  ...                                ...               ...
# 112      113      M  ...                                 NO        Not placed
# 113      114      M  ...                                 NO        Not placed
# 114      115      M  ...                                 NO        Not placed
# 115      116      M  ...                                 NO        Not placed
# 116      117      M  ...                                 NO        Not placed
#
# [117 rows x 9 columns]

# %%
k=j.loc[j['Section']=='A']
k
# Out:
#     Roll No Gender  ... registered_for_ Placement_Training  placement status
# 0         1      M  ...                                 NO        Not placed
# 1         2      F  ...                                yes            Placed
# 2         3      F  ...                                yes        Not placed
# 3         4      M  ...                                yes        Not placed
# 4         5      M  ...                                yes        Not placed
# 5         6      M  ...                                yes        Not placed
# 6         7      M  ...                                yes        Not placed
# 7         8      F  ...                                 NO        Not placed
# 8         9      M  ...                                yes        Not placed
# 9        10      M  ...                                yes        Not placed
# 10       11      F  ...                                 NO            Placed
# ...

# %%
j.isna().any()
# Out:
# Roll No                               False
# Gender                                False
# Section                               False
# SSC Percentage                        False
# inter_Diploma_percentage              False
# B.Tech_percentage                     False
# Backlogs                              False
# registered_for_ Placement_Training    False
# placement status                      False
# dtype: bool

# %%
j=j.fillna(method="ffill")
j
# Out:
#      Roll No Gender  ... registered_for_ Placement_Training  placement status
# 0          1      M  ...                                 NO        Not placed
# 1          2      F  ...                                yes            Placed
# 2          3      F  ...                                yes        Not placed
# 3          4      M  ...                                yes        Not placed
# 4          5      M  ...                                yes        Not placed
# ..       ...    ...  ...                                ...               ...
# 112      113      M  ...                                 NO        Not placed
# 113      114      M  ...                                 NO        Not placed
# 114      115      M  ...                                 NO        Not placed
# 115      116      M  ...                                 NO        Not placed
# 116      117      M  ...                                 NO        Not placed
#
# [117 rows x 9 columns]

# %%
j.isna().any()
# Out:
# Roll No                               False
# Gender                                False
# Section                               False
# SSC Percentage                        False
# inter_Diploma_percentage              False
# B.Tech_percentage                     False
# Backlogs                              False
# registered_for_ Placement_Training    False
# placement status                      False
# dtype: bool

# %%
x = j[['SSC Percentage','inter_Diploma_percentage','Backlogs']].values
y= j['B.Tech_percentage'].values

# %%
x.shape
# Out:
# (117, 3)

# %%
y.shape
# Out:
# (117,)

# %%
X_train,X_test,Y_train,Y_test=train_test_split(x,y, test_size = 0.2 , random_state = 0)

# %%
model=LinearRegression()
model.fit(X_train,Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
model.intercept_
# Out:
# 35.057354321886265

# %%
model.coef_
# Out:
# array([ 0.06554206,  0.33857249, -1.14272442])

# %%
predicted_btech=model.predict(X_test)
predicted_btech.shape
# Out:
# (24,)

# %%
X_test.shape
# Out:
# (24, 3)

# %%
print('R2 error:',metrics.r2_score(Y_test, predicted_btech))
# Out:
# R2 error: 0.7542355177020978

# %%
print('R2 error:',metrics.mean_absolute_error(Y_test, predicted_btech))
# Out:
# R2 error: 4.5371144478534156
